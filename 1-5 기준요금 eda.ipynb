# %%
import pandas as pd
import numpy as np
import datetime 
import seaborn as sns
import glob

# %%
df= pd.read_csv('master_final_220708_택시요금추가.csv')
df.head()
# Out:
#   cartype                 예정시간                 배차시간                 승차시간  \
# 0    중형승합  2018-01-23 00:04:00  2018-01-23 00:18:42  2018-01-23 00:34:08
# 1    중형승합  2018-01-23 00:17:00  2018-01-23 00:50:37  2018-01-23 01:19:22
# 2    중형승합  2018-01-23 00:17:06  2018-01-23 00:17:39  2018-01-23 00:30:00
# 3    중형승합  2018-01-23 00:47:00  2018-01-23 00:51:19  2018-01-23 01:09:33
# 4    중형승합  2018-01-23 01:08:00  2018-01-23 01:44:17  2018-01-23 02:06:53
#
#   startpos1 startpos2 endpos1 endpos2   direction   start_lat  ...  duration  \
# 0       성북구     장위제1동    동대문구     회기동    장위제1동회기동  127.043713  ...   648.464
# 1       중랑구     면목제7동     노원구    상계1동   면목제7동상계1동  127.086985  ...  1318.675
# 2       성북구     정릉제3동     강북구   수유제3동  정릉제3동수유제3동  127.004186  ...   864.161
# 3       구로구     고척제2동     관악구     은천동    고척제2동은천동  126.858712  ...  1652.785
# 4      동대문구       회기동     성북구   장위제2동    회기동장위제2동  127.055313  ...   598.639
#
# ...
